# %%
import numpy as np

from matplotlib import pyplot as plt
import seaborn as sbn
from matplotlib import animation
from IPython.display import HTML 
from functools import partial

# %%
# %matplotlib inline

# %%
def plot_animation(sample_sizes, samples, func=np.mean):
    fig = plt.figure()
    ax = plt.axes()

    def animate_full(samples, i):
        # w i-tej klatce wyświetl wynik dla i-tego rozmiaru z wymaganych
        smpl = np.asarray(samples[:sample_sizes[i]])
        means = func(smpl, axis=1)
        ax.cla()
        
        r = plt.hist(means, bins=50)
        return (r,)

    animate = partial(animate_full, samples)

    # call the animator. blit=True means only re-draw the parts that have changed.
    anim = animation.FuncAnimation(fig, animate, frames=len(sample_sizes), interval=100, blit=False)
    js = anim.to_jshtml()
    plt.close(anim._fig)
    return HTML(js)

# %% [markdown]
# # Simple Introduction

# %%
NB_SAMPLES = 100
SAMPLE_SIZE = 1000

# %%
samples = np.asarray([np.random.exponential(size=SAMPLE_SIZE) for _ in range(NB_SAMPLES)])
samples.shape

means = samples.mean(axis=1)
plt.hist(means)
# Out:
# (array([  3.,   0.,   5.,   9.,  22.,  21.,  16.,  10.,   7.,   7.]),
#  array([ 0.92692634,  0.94003312,  0.9531399 ,  0.96624668,  0.97935346,
#          0.99246024,  1.00556702,  1.0186738 ,  1.03178058,  1.04488736,
#          1.05799414]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Animation

# %%
MAX_SAMPLE_SIZE = 1000
MIN_SAMPLE_SIZE = 2
STEP = 8
SAMPLE_SIZES = range(MIN_SAMPLE_SIZE, MAX_SAMPLE_SIZE, STEP)
print(len(SAMPLE_SIZES))

samples = [np.random.exponential(size=SAMPLE_SIZE) for i in range(MAX_SAMPLE_SIZE)]
# Out:
# 125

# %%
plot_animation(SAMPLE_SIZES, samples, np.mean)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img0cf3241568cf4906ad419af56d2adb87">
#     <br>
#     <input id="_anim_slider0cf3241568cf4906ad419af56d2adb87" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim0cf3241568cf4906ad419af56d2adb87.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim0cf3241568cf4906ad419af56d2adb87.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim0cf3241568cf4906ad419af56d2adb87.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim0cf3241568cf4906ad419af56d2adb87.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim0cf3241568cf4906ad419af56d2adb87.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim0cf3241568cf4906ad419af56d2adb87.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim0cf3241568cf4906ad419af56d2adb87.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim0cf3241568cf4906ad419af56d2adb87.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim0cf3241568cf4906ad419af56d2adb87.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim0cf3241568cf4906ad419af56d2adb87.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select0cf3241568cf4906ad419af56d2adb87" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img0cf3241568cf4906ad419af56d2adb87";
#     var slider_id = "_anim_slider0cf3241568cf4906ad419af56d2adb87";
#     var loop_select_id = "_anim_loop_select0cf3241568cf4906ad419af56d2adb87";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMS4wLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvpW3flQAAFV5JREFUeJzt3H9M1Pfhx/HXbVdqrAtiC6t4dHoe\
# Y3CUHylM7LZW5pR6Nrd2sQyXaRubsK0kZv5R/SZL+W7EpiTr/GNj6Xatq3bLYK1bB1mFWa2yhszR\
# W2lcd93ADpW7mA0stbYrIPD+/tF4GQFbv3Dy+bzn85E04XOfT68va8Iz9+E4jzHGCAAAy3zM6QEA\
# AMwGAQMAWImAAQCsRMAAAFYiYAAAKxEwAICVCBgAwEoEDABgJQIGALASAQMAWImAAQCsRMAAAFYi\
# YAAAKxEwAICVCBgAwEoEDABgJQIGALASAQMAWImAAQCsRMAAAFYiYAAAKxEwAICVCBgAwEoEDABg\
# JQIGALASAQMAWImAAQCsRMAAAFYiYAAAKxEwAICVCBgAwEoEDABgJQIGALASAQMAWMnr9ICr5aab\
# btLy5cudngEAVjl16pSGhoacnnFF/msDtnz5ckWjUadnAIBVysrKnJ5wxbiFCACwEgEDAFiJgAEA\
# rETAAABWcjxg27ZtU1ZWlgoLC2c8b4zR9u3bFQgEVFRUpFdffXWeFwIA3MjxgD3wwAPq6Oi47Pn2\
# 9nb19fWpr69PkUhE3/rWt+ZxHQDArRwP2B133KElS5Zc9nxra6u2bt0qj8ejiooKvf322zp79uw8\
# LgQAuJHjAfsoiURCOTk5yWOfz6dEIuHgIgCAG7j+F5mNMdMe83g8M14biUQUiUQkSYODg7P+by7/\
# nxdmfPxU48ZZPycApNLlvk9J1873Kte/AvP5fBoYGEgex+NxZWdnz3htbW2totGootGoMjMz52si\
# AMABrg9YOBzWM888I2OMjh8/rvT0dC1dutTpWQAAhzl+C3Hz5s06duyYhoaG5PP59L3vfU8XL16U\
# JH3zm99UKBTSwYMHFQgEtHDhQj399NMOLwYAuIHjAWtubv7Q8x6PRz/+8Y/naQ0AwBauv4UIAMBM\
# CBgAwEoEDABgJQIGALASAQMAWImAAQCsRMAAAFYiYAAAKxEwAICVCBgAwEoEDABgJQIGALASAQMA\
# WImAAQCsRMAAAFYiYAAAKxEwAICVCBgAwEoEDABgJQIGALASAQMAWImAAQCsRMAAAFYiYAAAKxEw\
# AICVCBgAwEoEDABgJQIGALASAQMAWImAAQCsRMAAAFYiYAAAK7kiYB0dHcrLy1MgEFBjY+O082fO\
# nFFlZaVKS0tVVFSkgwcPOrASAOAmjgdsYmJCdXV1am9vVywWU3Nzs2Kx2JRrdu/ererqavX09Kil\
# pUUPPfSQQ2sBAG7heMC6u7sVCATk9/uVlpammpoatba2TrnG4/HonXfekSSdP39e2dnZTkwFALiI\
# 1+kBiURCOTk5yWOfz6c//elPU6757ne/q/Xr1+tHP/qR3nvvPR0+fHi+ZwIAXMbxV2DGmGmPeTye\
# KcfNzc164IEHFI/HdfDgQW3ZskWTk5PT/r1IJKKysjKVlZVpcHDwqm0GADjP8YD5fD4NDAwkj+Px\
# +LRbhHv37lV1dbUkafXq1RoZGdHQ0NC056qtrVU0GlU0GlVmZubVHQ4AcJTjASsvL1dfX5/6+/s1\
# NjamlpYWhcPhKdfccsstOnLkiCTpjTfe0MjICIECgGuc4wHzer1qampSVVWV8vPzVV1drWAwqPr6\
# erW1tUmSfvCDH+jJJ59UcXGxNm/erH379k27zQgAuLY4/iYOSQqFQgqFQlMea2hoSH5dUFCgrq6u\
# +Z4FAHAxx1+BAQAwGwQMAGAlAgYAsBIBAwBYiYABAKxEwAAAViJgAAArETAAgJUIGADASgQMAGAl\
# AgYAsBIBAwBYiYABAKxEwAAAViJgAAArETAAgJUIGADASgQMAGAlAgYAsBIBAwBYi

# %% [markdown]
# # Bernoulli / binomial
#
# Binomial is a set of bernoulli experiments

# %%
TRIAL_SIZE = 1000
NB_TRIALS = 100
P = 0.23284

# %%
BERNOULLI = False

# %%
if BERNOULLI:
    samples = []
    for i in range(TRIAL_SIZE):
        s = []
        for _ in range(NB_TRIALS):
            s.append(int(np.random.random()>P))
        samples.append(np.asarray(s))
    sums = np.asarray(samples).sum(axis=1)
else:
    sums=np.random.binomial(NB_TRIALS, P, TRIAL_SIZE)
plt.hist(sums)
# Out:
# (array([  16.,   62.,  115.,  260.,  190.,  198.,  107.,   28.,   22.,    2.]),
#  array([ 12. ,  14.6,  17.2,  19.8,  22.4,  25. ,  27.6,  30.2,  32.8,
#          35.4,  38. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Animation

# %%
MAX_TRIAL_SIZE = 1000
MIN_TRIAL_SIZE = 2
STEP = 8
TRIAL_SIZES = range(MIN_TRIAL_SIZE, MAX_TRIAL_SIZE, STEP)
print(len(TRIAL_SIZES))

if BERNOULLI:
    samples = []
    for i in range(MAX_TRIAL_SIZE):
        s = []
        for _ in range(NB_TRIALS):
            s.append(int(np.random.random()>P))
        samples.append(np.asarray(s)) 
else:
    samples = np.random.binomial(NB_TRIALS, P, MAX_TRIAL_SIZE)
# Out:
# 125

# %%
plot_animation(TRIAL_SIZES, samples, np.sum) if BERNOULLI\
    else plot_animation(TRIAL_SIZES, samples, lambda x, axis: x)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgc5b9870e0ebf406dae7358e8dff8b0ee">
#     <br>
#     <input id="_anim_sliderc5b9870e0ebf406dae7358e8dff8b0ee" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animc5b9870e0ebf406dae7358e8dff8b0ee.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animc5b9870e0ebf406dae7358e8dff8b0ee.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="animc5b9870e0ebf406dae7358e8dff8b0ee.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="animc5b9870e0ebf406dae7358e8dff8b0ee.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="animc5b9870e0ebf406dae7358e8dff8b0ee.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="animc5b9870e0ebf406dae7358e8dff8b0ee.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="animc5b9870e0ebf406dae7358e8dff8b0ee.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="animc5b9870e0ebf406dae7358e8dff8b0ee.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="animc5b9870e0ebf406dae7358e8dff8b0ee.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="animc5b9870e0ebf406dae7358e8dff8b0ee.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selectc5b9870e0ebf406dae7358e8dff8b0ee" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgc5b9870e0ebf406dae7358e8dff8b0ee";
#     var slider_id = "_anim_sliderc5b9870e0ebf406dae7358e8dff8b0ee";
#     var loop_select_id = "_anim_loop_selectc5b9870e0ebf406dae7358e8dff8b0ee";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMS4wLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvpW3flQAAEtNJREFUeJzt3H9oXXf9x/HX/RqzMdhquyW4eO4S\
# wx1Zcps0rTddRJzWYoPXeR0ys1Sd+wXZXNigA+sYLN2CP4LbCnORwR3FKULirEgCTQK2XcsYbOG6\
# yphX6RVy3b231SbK2lrosiaf7z9fL82Su/mtufncd/N8/HXPOZ/evj/cts+ek7Qh55wTAADG/I/v\
# AQAAuBQEDABgEgEDAJhEwAAAJhEwAIBJBAwAYBIBAwCYRMAAACYRMACASQQMAGASAQMAmETAAAAm\
# ETAAgEkEDABgEgEDAJhEwAAAJhEwAIBJBAwAYBIBAwCYRMAAACYRMACASQQMAGASAQMAmETAAAAm\
# ETAAgEkEDABgEgEDAJhEwAAAJhEwAIBJBAwAYBIBAwCYRMAAACYRMACASQQMAGBSle8ByuW6665T\
# Q0OD7zEAwJRsNqvZ2VnfY/xHLtuANTQ0KJVK+R4DAEyJxWK+R/iP8QgRAGASAQMAmETAAAAmETAA\
# gEneA3bvvfeqtrZWGzduXPa6c04PP/ywIpGI2tra9MYbb6zyhACASuQ9YHfffbcmJydLXp+YmFAm\
# k1Emk1EymdR3vvOdVZwOAFCpvAfslltu0YYNG0peHx0d1be//W2FQiF1dnbqnXfe0cmTJ1dxQgBA\
# JfIesA9TKBQUDoeLx0EQqFAoeJwIAFAJKv4fMjvnlpwLhULLrk0mk0omk5KkmZmZS/45Gx49sOz5\
# 7OCXL/k9AWAllfpzSlo7f1ZV/B1YEATK5XLF43w+r7q6umXX9vb2KpVKKZVKqaamZrVGBAB4UPEB\
# SyQS+sUvfiHnnF577TWtW7dO119/ve+xAACeeX+EuHPnTh05ckSzs7MKgkBPPvmk3nvvPUnSAw88\
# oHg8rvHxcUUiEV111VX62c9+5nliAEAl8B6w4eHhD7weCoX005/+dJWmAQBYUfGPEAEAWA4BAwCY\
# RMAAACYRMACASQQMAGASAQMAmETAAAAmETAAgEkEDABgEgEDAJhEwAAAJhEwAIBJBAwAYBIBAwCY\
# RMAAACYRMACASQQMAGASAQMAmETAAAAmETAAgEkEDABgEgEDAJhEwAAAJhEwAIBJBAwAYBIBAwCY\
# RMAAACYRMACASQQMAGASAQMAmETAAAAmETAAgEkVEbDJyUk1NTUpEolocHBwyfW3335b27Zt0+bN\
# m9XW1qbx8XEPUwIAKon3gM3Pz6uvr08TExNKp9MaHh5WOp1etOb73/++uru7dezYMY2MjOjBBx/0\
# NC0AoFJ4D9jU1JQikYgaGxtVXV2tnp4ejY6OLloTCoV05swZSdLp06dVV1fnY1QAQAWp8j1AoVBQ\
# OBwuHgdBoNdff33RmieeeEI7duzQc889p3PnzungwYOrPSYAoMJ4vwNzzi05FwqFFh0PDw/r7rvv\
# Vj6f1/j4uO68804tLCws+XHJZFKxWEyxWEwzMzNlmxkA4J/3gAVBoFwuVzzO5/NLHhHu27dP3d3d\
# kqRPf/rTOn/+vGZnZ5e8V29vr1KplFKplGpqaso7OADAK+8B6+joUCaT0fT0tObm5jQyMqJEIrFo\
# zQ033KBDhw5Jkv70pz/p/PnzBAoA1jjvAauqqtLQ0JC6urrU3Nys7u5uRaNR9ff3a2xsTJL0zDPP\
# 6IUXXtCmTZu0c+dOvfjii0seMwIA1hbv38QhSfF4XPF4fNG5gYGB4uuWlha9+uqrqz0WAKCCeb8D\
# AwDgUhAwAIBJBAwAYBIBAwCYRMAAACYRMACASQQMAGASAQMAmETAAAAmETAAgEkEDABgEgEDAJhE\
# wAAAJhEwAIBJBAwAYBIBAwCYRMAAACYRMACASQQMAGASAQMAmETAAAAmETAAgEkED

# %% [markdown]
# # Multinomial

# %%
NB_TRIALS = 100
TRIAL_SIZE = 1000
P = np.random.random(size=4)
P = P / P.sum()
print(P)
# Out:
# [ 0.3406401   0.3373749   0.12534653  0.19663846]

# %%
samples = [np.random.multinomial(NB_TRIALS, P) for _ in range(TRIAL_SIZE)]

sums = [x[0] for x in samples]
plt.hist(sums)
# Out:
# (array([   2.,   33.,   75.,  252.,  251.,  262.,  100.,   21.,    2.,    2.]),
#  array([ 18. ,  21.6,  25.2,  28.8,  32.4,  36. ,  39.6,  43.2,  46.8,
#          50.4,  54. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Animation

# %%
MAX_TRIAL_SIZE = 1000
MIN_TRIAL_SIZE = 2
STEP = 8
TRIAL_SIZES = range(MIN_TRIAL_SIZE, MAX_TRIAL_SIZE, STEP)
len(TRIAL_SIZES)
# Out:
# 125

# %%
samples = np.asarray([np.random.multinomial(NB_TRIALS, P) for _ in range(MAX_TRIAL_SIZE)])

# %%
plot_animation(TRIAL_SIZES, samples, lambda x, axis: x[:,0])
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img6497111745f647dbb8edc5487bfce938">
#     <br>
#     <input id="_anim_slider6497111745f647dbb8edc5487bfce938" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim6497111745f647dbb8edc5487bfce938.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim6497111745f647dbb8edc5487bfce938.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim6497111745f647dbb8edc5487bfce938.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim6497111745f647dbb8edc5487bfce938.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim6497111745f647dbb8edc5487bfce938.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim6497111745f647dbb8edc5487bfce938.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim6497111745f647dbb8edc5487bfce938.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim6497111745f647dbb8edc5487bfce938.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim6497111745f647dbb8edc5487bfce938.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim6497111745f647dbb8edc5487bfce938.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select6497111745f647dbb8edc5487bfce938" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img6497111745f647dbb8edc5487bfce938";
#     var slider_id = "_anim_slider6497111745f647dbb8edc5487bfce938";
#     var loop_select_id = "_anim_loop_select6497111745f647dbb8edc5487bfce938";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMS4wLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvpW3flQAAFYNJREFUeJzt3H9sVXf9x/HXkbtC8AeU0WbUW0cv\
# t6vt7UpJWiiaLVSD3e7MnUtKKVv4MUg6pXGRP5wmZlUaDDVGErX6x92Q/TC2bpisNdAymcM/UCzX\
# FZVV5A6L672SeFt+blnpr8/3D8LN+m0LLdJ77oc9H8mSnnM/9/bN4TOe3NvLdYwxRgAAWOZjbg8A\
