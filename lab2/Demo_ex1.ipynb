# %%
% matplotlib inline

# %%
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sbn

from plotter import MixturePlotter
from mixture_distribution import CombinedGaussians

# %% [markdown]
# # Single Gaussian

# %%
sample_size = 10000
mn, mx = 0, 250

# %%
cg = CombinedGaussians(1, sample_size, lower_bound=mn, upper_bound=mx)#, params=[[240], [255]])

# %%
MixturePlotter.visualise_sample(cg, params_from_sample=True, visualise_var=True)

# %%
MixturePlotter.visualise_pmf(cg, figsize=(18,10), visualise_var=True, params_from_sample=True)

# %% [markdown]
# # 2 Gaussians Mixture

# %%
sample_size = 10000
mn, mx = 0, 250

# %%
cg = CombinedGaussians(2, sample_size, lower_bound=mn, upper_bound=mx)#, params=[[240], [255]])

# %%
print('mean:', np.asarray(cg.get_full_sample()).mean())
# Out:
# mean: 154.259305997

# %%
MixturePlotter.visualise_sample(cg, params_from_sample=False)

# %%
MixturePlotter.visualise_pmf(cg, figsize=(18,10), visualise_var=True, params_from_sample=True)

# %% [markdown]
# # 3 Gaussians Mixture

# %%
sample_size = 10000
mn, mx = 0, 250

# %%
cg = CombinedGaussians(3, sample_size, lower_bound=mn, upper_bound=mx)#, params=[[240], [255]])

# %%
print('mean:', np.asarray(cg.get_full_sample()).mean())
# Out:
# mean: 86.6131371548

# %%
MixturePlotter.visualise_sample(cg, params_from_sample=False)

# %%
MixturePlotter.visualise_pmf(cg, figsize=(18,10), visualise_var=True, params_from_sample=False)

# %% [markdown]
# # 6 Gaussians Mixture

# %%
sample_size = 10000
mn, mx = 0, 500

# %%
cg = CombinedGaussians(6, sample_size, lower_bound=mn, upper_bound=mx)#, params=[[240], [255]])

# %%
MixturePlotter.visualise_sample(cg, params_from_sample=False)

# %%
MixturePlotter.visualise_pmf(cg, figsize=(18,10), visualise_var=True, params_from_sample=False)
